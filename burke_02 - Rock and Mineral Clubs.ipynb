# %% [markdown]
# # Rock and Mineral Clubs
#
# Scrape all of the rock and mineral clubs listed at https://rocktumbler.com/blog/rock-and-mineral-clubs/ (but don't just cut and paste!)
#
# Save a CSV called `rock-clubs.csv` with the name of the club, their URL, and the city they're located in.
#
# **Bonus**: Add a column for the state. There are a few ways to do this, but knowing that `element.parent` goes 'up' one element might be helpful.
#
# * _**Hint:** The name of the club and the city are both inside of td elements, and they aren't distinguishable by class. Instead you'll just want to ask for all of the tds and then just ask for the text from the first or second one._
# * _**Hint:** If you use BeautifulSoup, you can select elements by attributes other than class or id - instead of `doc.find_all({'class': 'cat'})` you can do things like `doc.find_all({'other_attribute': 'blah'})` (sorry for the awful example)._
# * _**Hint:** If you love `pd.read_html` you might also be interested in `pd.concat` and potentially `list()`. But you'll have to clean a little more!_

# %%
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import re
# Out:
# /Users/shaneburke/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
driver = webdriver.Chrome()

# %%
url = 'https://rocktumbler.com/blog/rock-and-mineral-clubs'
driver.get(url)

# %%
rock_clubs = []
sections = driver.find_elements_by_tag_name("section")[1:-2]

for section in sections:
    
    state_heading = section.find_elements_by_tag_name("h3")[0].text.strip()
    #print(state_heading)
    
    state = re.findall(r'^(.+) Rock and Mineral Clubs',state_heading)[0]
    #print(state)
        
    #the green headings are their own tables, so we'll use the second table per section
    rows = section.find_elements_by_tag_name("table")[1].find_elements_by_tag_name("tr")  
    for row in rows:
        club = row.find_elements_by_tag_name("td")[0].text.strip()
        city = row.find_elements_by_tag_name("td")[1].text.strip()
        club_link = row.find_element_by_tag_name("a").get_attribute("href")
        #print(club, "||", city, "||", club_link)
        
        rock_clubs.append({'state': state, 
                           'club': club,
                           'city': city,
                          'club link': club_link})

# %%
print(rock_clubs)
# Out:
# [{'state': 'Alabama', 'club': 'Alabama Mineral & Lapidary Society', 'city': 'Birmingham', 'club link': 'http://www.lapidaryclub.com/'}, {'state': 'Alabama', 'club': 'Dothan Gem & Mineral Club', 'city': 'Dothan', 'club link': 'http://www.wiregrassrockhounds.com/'}, {'state': 'Alabama', 'club': 'Huntsville Gem and Mineral Society', 'city': 'Huntsville', 'club link': 'http://huntsvillegms.org/'}, {'state': 'Alabama', 'club': 'Mobile Rock & Gem Society', 'city': 'Mobile', 'club link': 'http://www.mobilerockandgem.com/'}, {'state': 'Alabama', 'club': 'Montgomery Gem & Mineral Society', 'city': 'Montgomery', 'club link': 'http://montgomerygemandmineralsociety.com/mgms/'}, {'state': 'Alaska', 'club': 'Chugach Gem & Mineral Society', 'city': 'Anchorage', 'club link': 'http://www.chugachgemandmineralsociety.com/'}, {'state': 'Alaska', 'club': 'Mat-Su Rock and Mineral Club', 'city': 'Palmer', 'club link': 'http://matsurockclub.com/'}, {'state': 'Arizona', 'club': 'Apache Junction Rock and Gem Club', 'city': 'Apache Junction', 'club link': 'http://www.ajrockclub.com/'}, {'state': 'Arizona', 'club': 'Black Canyon City Rock Club', 'city': 'Black Canyon City', 'club link': 'http://www.bccrockclub.mysite.com/'}, {'state': 'Arizona', 'club': 'Daisy Mountain Rock & Mineral Club', 'city': 'Anthem', 'club link': 'http://www.dmrmc.com/'}, {'state': 'Arizona', 'club': 'Gila County Gem & Mineral Society', 'city': 'Miami', 'club link': 'http://gilagem.org/'}, {'state': 'Arizona', 'club': 'Huachuca Mineral and Gem Club', 'city': 'Sierra Vista', 'club link': 'http://www.huachucamineralandgemclub.info/'}, {'state': 'Arizona', 'club': 'Lake Havasu Gem & Mineral Society', 'city': 'Lake Havasu City', 'club link': 'http://www.lakehavasugms.org/'}, {'state': 'Arizona', 'club': 'Mineralogical Society of Arizona', 'city': 'Scottsdale', 'club link': 'http://www.msaaz.org/'}, {'state': 'Arizona', 'club': 'Mingus Gem & Mineral Club', 'city': 'Cottonwood', 'club link': 'http://www.mingusclub.org/'}, {'state': 'Arizona', 'club': 'Mohave County Gemstoners', 'city': 'Kingman', 'club link': 'http://www.gemstoners.org/'}, {'state': 'Arizona', 'club': 'Old Pueblo Lapidary Club', 'city': 'Tucson', 'club link': 'http://www.lapidaryclub.org/'}, {'state': 'Arizona', 'club': 'Pinal Gem and Mineral Society', 'city': 'Coolidge', 'club link': 'https://www.pinalgeologymuseum.org/index.php/pinal-gem-mineral-society/about-pgms'}, {'state': 'Arizona', 'club': 'Prescott Gem & Mineral Club', 'city': 'Prescott Valley', 'club link': 'http://www.prescottgemmineral.org/'}, {'state': 'Arizona', 'club': 'Quartzsite Roadrunners Gem & Mineral Club', 'city': 'Quartzsite', 'club link': 'http://www.qrgmc.org/'}, {'state': 'Arizona', 'club': 'Rockhounds West', 'city': 'Phoenix', 'club link': 'http://rockhounds.scwclubs.com/'}, {'state': 'Arizona', 'club': 'Sedona Gem & Mineral Club', 'city': 'Sedona', 'club link': 'http://www.sedonagemandmineral.org/'}, {'state': 'Arizona', 'club': 'Silvery Colorado River Rock Club', 'city': 'Bullhead City', 'club link': 'http://scrrc.blogspot.com/'}, {'state': 'Arizona', 'club': 'Sunsites Gem and Mineral Club', 'city': 'Pearce', 'club link': 'https://sites.google.com/site/cochisecountyrock/'}, {'state': 'Arizona', 'club': 'Tucson Gem and Mineral Society', 'city': 'Tucson', 'club link': 'http://www.tgms.org/'}, {'state': 'Arizona', 'club': 'Verde River Rockhounds', 'city': 'Cottonwood', 'club link': 'http://www.verderiverrockhounds.com/'}, {'state': 'Arizona', 'club': 'West Valley Rock & Mineral Club', 'city': 'Buckeye', 'club link': 'http://www.westvalleyrockandmineralclub.com/'}, {'state': 'Arizona', 'club': 'White Mountain Gem & Mineral Club', 'city': 'Show Low', 'club link': 'http://whitemountain-azrockclub.org/'}, {'state': 'Arizona', 'club': 'Wickenburg Gem and Mineral Society', 'city': 'Wickenburg', 'club link': 'http://www.wickenburggms.org/'}, {'state': 'Arkansas', 'club': 'Central Arkansas Gem, Mineral and Geology Society', 'city': 'Little Rock', 'clu ...

# %%
df = pd.DataFrame(rock_clubs)
df
# Out:
#          state                                   club        city  \
# 0      Alabama     Alabama Mineral & Lapidary Society  Birmingham
# 1      Alabama              Dothan Gem & Mineral Club      Dothan
# 2      Alabama     Huntsville Gem and Mineral Society  Huntsville
# 3      Alabama              Mobile Rock & Gem Society      Mobile
# 4      Alabama       Montgomery Gem & Mineral Society  Montgomery
# ..         ...                                    ...         ...
# 481  Wisconsin             Weis'n'Miners Geology Club     Menasha
# 482  Wisconsin           Wisconsin Geological Society  West Allis
# 483    Wyoming                   Cody 59ers Rock Club        Cody
# 484    Wyoming       Riverton Mineral and Gem Society    Riverton
# 485    Wyoming  Wyoming State Mineral and Gem Society        Cody
#
#                                            club link
# 0                       http://www.lapidaryclub.com/
# 1                http://www.wiregrassrockhounds.com/
# 2                          http://huntsvillegms.org/
# 3                   http://www.mobilerockandgem.com/
# 4    http://montgomerygemandmineralsociety.com/mgms/
# ..                                               ...
# 481      http://www.weismuseum.org/geology-club.html
# 482             http://www.wisgeologicalsociety.com/
# 483                        http://www.cody59ers.com/
# 484                      http://www.rivertonmgs.com/
# 485               http://wymineralandgemsociety.org/
#
# [486 rows x 4 columns]

# %%
df.to_csv('rock-clubs.csv', index=False)
