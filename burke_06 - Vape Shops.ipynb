# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Import what you need

# %%
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import re
import time
# Out:
# /Users/shaneburke/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
driver = webdriver.Chrome()

# %%
#url = "https://jportal.mdcourts.gov/license/pbPublicSearch.jsp#"
#driver.get(url)

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages, or you can close and re-open Chrome.
#
# - Check the checkbox, then submit the form to accept their terms of service
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**
#
# - *TIP: if something doesn't have anything special about it, xpath might be your best bet*

# %%
url = 'https://jportal.mdcourts.gov/license/index_disclaimer.jsp'
driver.get(url)

checkbox = driver.find_element_by_id("checkbox")
checkbox.click()

submit_form = driver.find_element_by_tag_name("form")
submit_form.submit()

# %% [markdown]
# Now click the **Search License Records** link up top in the navigation to get to the search page.
#
# - *TIP: Honestly you could also just visit the URL directly now since you filled out that terms of service thing*

# %%
url = 'https://jportal.mdcourts.gov/license/pbPublicSearch.jsp'
driver.get(url)

# %% [markdown]
# ### Perform your search
#
# Pick "Statewide" for the jurisdiction dropdown, and `VAP%` into the Trade Name field. The `%` is a wildcard.
#
# *TIP: I wish I could put this on CourseWorks, but it looks too ugly: [Selenium snippets](http://jonathansoma.com/lede/foundations-2018/classes/selenium/selenium-snippets/) will help you with the dropdown*

# %%
#picking statewide
jurisdiction_pick = driver.find_element_by_id("slcJurisdiction")
statewide_option = jurisdiction_pick.find_elements_by_tag_name("option")[1]
statewide_option.click()

#vap% into the trade name field
trade_name_field = driver.find_element_by_id("txtTradeName")
trade_name_field.send_keys("VAP%")

# %% [markdown]
# And now, of course, **submit the form**.
#
# - *TIP: Since scrolling to buttons can be a pain, sometimes it's easier to select the form and use `.submit()` instead of `.click()`ing the button*

# %%
form = driver.find_element_by_tag_name("form")
form.submit()

# %% [markdown]
# ## (Try to) scrape the results
#
# Let's start by just **printing this stuff**. We'll save it as a dataframe later on.
#
# For now, just scrape **each store's name**, then cry a little. Fact: this is an impossible and miserable page.

# %%
store_names = driver.find_elements_by_class_name("searchlistitem")

for store in store_names:
    print(store.text.strip())
# Out:
# VAPE IT STORE I
# VAPE IT STORE II
# VAPEPAD THE
# VAPE LOFT THE
# VAPE N CIGAR

# %%
# pages = [0, 1, 2, 3, 4]

# for page in pages:
        
#         field_list = driver.find_elements_by_class_name("searchfieldtitle")
        
#         for field in field_list:
#             store = field.find_element_by_class_name("searchlistitem")
#             print(store.text.strip())
#             try:
#                 detail_link = field.find_element_by_tag_name("a")
#                 detail_link.click()
                
                
#                 driver.navigate().back()
#             except: 
#                 pass
        
        
        
        
        
#         try:
#             next_button = driver.find_elements_by_tag_name("nobr")[-1]
#             if next_button.text.strip == "Next":
#                 next_button.click()
#             else:
#                 pass
#         except:
#             pass

# %% [markdown]
# To avoid struggling with the search results page, we're going to use the **detail page** instead. Try to figure out how to select it and click it inside of your `for` loop.
#
# - *TIP: Instead of just looking for an `a` or an `img`, you might want to look for one of its parents first, then click. This might affect the way you print out the shop's name, too*
# }- *TIP: Not all of them have links! You can wrap in try/except to skip it, or you can check to see if the shop's status is Pending.*

# %%
#Jumped a little ahead and tried to do the whole next question first. Here is what I did for the detail links.

field_list = driver.find_elements_by_class_name("searchfieldtitle")
        
    for field in field_list:
        store = field.find_element_by_class_name("searchlistitem")
        print(store.text.strip())
            
        try:
            detail_link = field.find_element_by_tag_name("a")
            detail_link.click()
        except:
            pass
# Out:
#   File "<ipython-input-11-589b311599cc>", line 5
#     for field in field_list:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Okay, now let's get to action. For each result, **click the link to the detail page** and print out the following information:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# If it doesn't have a detail page, just print out the name and that's all we need.
#
# - *TIP: `try`/`except` is probably going to be your friend. What's it do?
# - *TIP: When you're done getting the information, you probably want to click back to the search results*
# - *TIP: You might enjoy `find_element_by_partial_link_text` to do that*
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
#
# > **IMPORTANT NOTE:** This is doomed!!!! It's useful to do, but your current process is doomed. Once you get a `stale element reference` error move on to the next cell.

# %%
pages = [0, 1, 2, 3, 4]

for page in pages:
        
        field_list = driver.find_elements_by_class_name("searchfieldtitle")
        
        for field in field_list:
            store = field.find_element_by_class_name("searchlistitem")
            print(store.text.strip())
            
            try:
                detail_link = field.find_element_by_tag_name("a")
                detail_link.click()
                
                mailing_address = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[0].text.strip()
                print(mailing_address)
                print("-")
                
                location_address = driver.find_elements_by_class_name("tablecelltext")[1].find_elements_by_tag_name("td")[0].text.strip()
                print(location_address)
                print("-")

                license_info = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[1].text.strip()
                print(license_info)
                print("-")
                
                amount_paid = driver.find_elements_by_class_name("rt")[-1].text.strip()
                print(amount_paid)
                print("-")
                
                issued_by = driver.find_elements_by_tag_name('table')[5].find_elements_by_class_name("tablecelltext")[0].text.strip()
                print(issued_by)
                
                
                driver.execute_script("window.history.go(-1)")
            except: 
                pass
            
            print("~*~*~")
        
        
        
        
        
        try:
            next_button = driver.find_elements_by_tag_name("nobr")[-1]
            if next_button.text.strip == "Next":
                next_button.click()
            else:
                pass
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-b5ba53f23f75> in <module>
#       6
#       7         for field in field_list:
# ----> 8             store = field.find_element_by_class_name("searchlistitem")
#       9             print(store.text.strip())
#      10
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_class_name(self, name)
#     396             element = element.find_element_by_class_name('foo')
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#     400     def find_elements_by_class_name(self, name):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     656                 value = '[name="%s"]' % value
#     657
# --> 658         return self._execute(Command.FIND_CHILD_ELEMENT,
#     659                              {"using": by, "value": value})['value']
#     660
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".searchlistitem"}
#   (Session info: chrome=87.0.4280.88)

# %% [markdown]
# ### Stale message reference
#
# Once you navigate away from a page, and you go back to it, you (sometimes, usually) can't use the variables from the first time you were on the page. So, we got a list of results when we first visited, clicked to the details page, clicked back, and now our original list is "stale."
#
# This is sad.
#
# Let's try this again: loop through the results and create a dataframe with `name` and `url` columns. And yes, some of them won't have URLs. No clicking links, just saving URLs.

# %%
store_info = []

pages = [0, 1, 2, 3, 4]

start_url = "https://jportal.mdcourts.gov/license/pbSearchResult.jsp?slcJurisdiction=50&txtTradeName=VAP%25&txtOwnerName=&txtLocationStreetName=&slcYear=2020&slcSortBy=ownername&pager.offset=0"
driver.get(start_url)

for page in pages:
        
    field_list = driver.find_elements_by_class_name("searchfieldtitle")

    for field in field_list:
        store = field.find_element_by_class_name("searchlistitem")
        #print(store.text.strip())

        try:
            detail_link = field.find_element_by_tag_name("a")
            detail_url = detail_link.get_attribute('href')

        except: 
            detail_url = "pending"

        #print(detail_url)

        store_info.append({"store" : store.text.strip(), "url": detail_url})

    try:
        next_button = driver.find_elements_by_tag_name("nobr")[-1]
        if "Next" in next_button.text.strip():
            next_button.click()

    except:
        pass

# %%
df_stores = pd.DataFrame(store_info)
df_stores.head()
df_stores.tail()
# Out:
#               store                                                url
# 19   VAPOR EMPORIUM  https://jportal.mdcourts.gov/license/pbLicense...
# 20      VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 21      VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 22    VAPORS LOUNGE  https://jportal.mdcourts.gov/license/pbLicense...
# 23  VAPERS RING THE  https://jportal.mdcourts.gov/license/pbLicense...

# %% [markdown]
# ### Getting all of the results
#
# After you've looped through the results on one page, we're going to want to go to the next page! Add a line to make it click the 'Next' button down at the bottom
#
# - *TIP: `find_element_by_partial_link_text` will be your friend*
# - *TIP: You might need to do the scrolling thing to get it onto the screen (and by that I mean, you WILL need to, so you should)*
#
# Confirm that it moves to the next page (it doesn't need to scrape anything yet)

# %%
#Did my original scrape with all 5 pages

# %% [markdown]
# ### Wrapping with `while`
#
# > Go back to the first page of results before you try to run this
#
# You have a bunch of scraping code. It clicks the next button, then it stops. But you'd like it to go back up to the top! You can make that happen with a special `while` loop.
#
# ```python
# while True:
#     # Scrape your stuff
#     # Click next button
# ```
#
# This will go on FOREVER AND EVER until there is an error (when it can't find the Next button on the last page of results, you'll get a `NoSuchElement` error when it tries to find the next button).
#
# - *Tip: Print out "Scraping a new page" every time you visit a new page, just to check that it's working*

# %%
store_info = []

start_url = "https://jportal.mdcourts.gov/license/pbSearchResult.jsp?slcJurisdiction=50&txtTradeName=VAP%25&txtOwnerName=&txtLocationStreetName=&slcYear=2020&slcSortBy=ownername&pager.offset=0"
driver.get(start_url)

has_next_page = True

while has_next_page: 
        
    field_list = driver.find_elements_by_class_name("searchfieldtitle")

    for field in field_list:
        store = field.find_element_by_class_name("searchlistitem")
        #print(store.text.strip())

        try:
            detail_link = field.find_element_by_tag_name("a")
            detail_url = detail_link.get_attribute('href')

        except: 
            detail_url = "pending"

        #print(detail_url)

        store_info.append({"store" : store.text.strip(), "url": detail_url})

    next_button = driver.find_elements_by_tag_name("nobr")[-1]

    if "Next" in next_button.text.strip():
        has_next_page = True
        next_button.click()
    else:
        has_next_page = False

# %%
df_stores = pd.DataFrame(store_info)
df_stores.head()
df_stores.tail()
# Out:
#               store                                                url
# 19   VAPOR EMPORIUM  https://jportal.mdcourts.gov/license/pbLicense...
# 20      VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 21      VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 22    VAPORS LOUNGE  https://jportal.mdcourts.gov/license/pbLicense...
# 23  VAPERS RING THE  https://jportal.mdcourts.gov/license/pbLicense...

# %% [markdown]
# ### Making it perfect
#
# > Go back to the first page of results before you try to run this
#
# Wrap all of your code in a `try`/`except` so that it doesn't finish with an error and you'll be good to go.
#
# **Confirm your list has all of the vape shops in it.** If not, check where you are creating your empty list (`[]`) - if you do it in the wrong spot, it will overwrite your list every time you visit a page.

# %%
store_info = []

start_url = "https://jportal.mdcourts.gov/license/pbSearchResult.jsp?slcJurisdiction=50&txtTradeName=VAP%25&txtOwnerName=&txtLocationStreetName=&slcYear=2020&slcSortBy=ownername&pager.offset=0"
driver.get(start_url)

has_next_page = True

try:
    while has_next_page: 

        field_list = driver.find_elements_by_class_name("searchfieldtitle")

        for field in field_list:
            store = field.find_element_by_class_name("searchlistitem")
            #print(store.text.strip())

            try:
                detail_link = field.find_element_by_tag_name("a")
                detail_url = detail_link.get_attribute('href')

            except: 
                detail_url = "pending"

            #print(detail_url)

            store_info.append({"store" : store.text.strip(), "url": detail_url})

        next_button = driver.find_elements_by_tag_name("nobr")[-1]

        if "Next" in next_button.text.strip():
            has_next_page = True
            next_button.click()
        else:
            has_next_page = False
            
except:
    pass

# %%
df_stores = pd.DataFrame(store_info)
df_stores.head()
df_stores.tail()
# Out:
#               store                                                url
# 19   VAPOR EMPORIUM  https://jportal.mdcourts.gov/license/pbLicense...
# 20      VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 21      VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 22    VAPORS LOUNGE  https://jportal.mdcourts.gov/license/pbLicense...
# 23  VAPERS RING THE  https://jportal.mdcourts.gov/license/pbLicense...

# %% [markdown]
# ### Save this data as a csv
#
# The filename should be `vape-shops-basic.csv`. You should have 24 rows.

# %%
df_stores.to_csv('vape-shops-basic.csv', index=False)

# %%
#CSV looks right in Excel

# %% [markdown]
# # Okay, let's scrape!
#
# All right, get the actual data!
#
# ### Look at the URL of your first row
#
# - *TIP: Remember `pd.set_option('display.max_colwidth', None)` will let you see alllll of your strings*

# %%
pd.set_option('display.max_colwidth', None)
df_stores
# Out:
#                 store  \
# 0     VAPE IT STORE I
# 1    VAPE IT STORE II
# 2         VAPEPAD THE
# 3       VAPE LOFT THE
# 4        VAPE N CIGAR
# 5        VAPE N CIGAR
# 6           VAPE DOJO
# 7        VAPE BIRD II
# 8           VAPE BIRD
# 9   VAPORFI SOUTHSIDE
# 10         VAPE DO JO
# 11        VAPE PLANET
# 12          VAPE PLUS
# 13        VAPE JUNGLE
# 14      VAPE JUNGLE 4
# 15        VAPE SOCIAL
# 16        VAPE SWITCH
# 17          VAPEWERKS
# 18          VAPIST MD
# 19     VAPOR EMPORIUM
# 20        VAPOR VILLA
# 21        VAPOR VILLA
# 22      VAPORS LOUNGE
# 23    VAPERS RING THE
#
#                                                                               url
# 0                                                                         pending
# 1                                                                         pending
# 2     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=EhcRmaKpHvo%3D
# 3     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AQQvPUEPdBc%3D
# 4     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rpdCUfaGICI%3D
# 5     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Ofer17GbEqI%3D
# 6                                                                         pending
# 7     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YrpYy3sMDmo%3D
# 8   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=8AvW%2FHiyaXQ%3D
# 9     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rftTtYeKd8U%3D
# 10                                                                        pending
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XLkC%2FxK0l1o%3D
# 12                                                                        pending
# 13    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=INj8yEazOBc%3D
# 14    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=K5SzjPZXD5g%3D
# 15    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=c7cwQbw6RrQ%3D
# 16                                                                        pending
# 17                                                                        pending
# 18  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=1Lwhqri%2Byjw%3D
# 19    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=MnOzyxlAHaA%3D
# 20  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=xQmQBJ%2F9Z4I%3D
# 21    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=uTwNVtGVItQ%3D
# 22    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mnI6lBaxYew%3D
# 23    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=uOemx26D8e0%3D

# %% [markdown]
# ### Okay, it doesn't have a URL!
#
# Let's drop all of the ones without URLs. You should be down to **17 rows**

# %%
#Saving old dataframe to join to later
df_stores_with_pending = df_stores

df_stores = df_stores[df_stores['url'] != "pending"]

df_stores
# Out:
#                 store  \
# 2         VAPEPAD THE
# 3       VAPE LOFT THE
# 4        VAPE N CIGAR
# 5        VAPE N CIGAR
# 7        VAPE BIRD II
# 8           VAPE BIRD
# 9   VAPORFI SOUTHSIDE
# 11        VAPE PLANET
# 13        VAPE JUNGLE
# 14      VAPE JUNGLE 4
# 15        VAPE SOCIAL
# 18          VAPIST MD
# 19     VAPOR EMPORIUM
# 20        VAPOR VILLA
# 21        VAPOR VILLA
# 22      VAPORS LOUNGE
# 23    VAPERS RING THE
#
#                                                                               url
# 2     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=EhcRmaKpHvo%3D
# 3     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AQQvPUEPdBc%3D
# 4     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rpdCUfaGICI%3D
# 5     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Ofer17GbEqI%3D
# 7     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YrpYy3sMDmo%3D
# 8   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=8AvW%2FHiyaXQ%3D
# 9     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rftTtYeKd8U%3D
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XLkC%2FxK0l1o%3D
# 13    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=INj8yEazOBc%3D
# 14    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=K5SzjPZXD5g%3D
# 15    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=c7cwQbw6RrQ%3D
# 18  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=1Lwhqri%2Byjw%3D
# 19    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=MnOzyxlAHaA%3D
# 20  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=xQmQBJ%2F9Z4I%3D
# 21    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=uTwNVtGVItQ%3D
# 22    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mnI6lBaxYew%3D
# 23    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=uOemx26D8e0%3D

# %% [markdown]
# Now look at the first one.

# %%
df_stores.head(1).url
# Out:
# 2    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=EhcRmaKpHvo%3D
# Name: url, dtype: object

# %% [markdown]
# ### Use Selenium to visit that page

# %%
# .iloc[0] means "give me the first row", kind of like .head(1), but
# it allows me to use .url to pull out the actual url. I only did this
# so that I could use a variable - you just needed to cut and paste
url = df_stores.iloc[0].url
url
# Out:
# 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=EhcRmaKpHvo%3D'

# %%
driver.get(url)

# %% [markdown]
# ### Now, just like you did before, grab the additional data
#
# You should probably save it into a dictionary! Don't try to put it into the dataframe yet, though. You want:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# .
#
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
# - *TIP: If you've gotten addicted to xpath, total amount paid and issued by might not work with it when doing other shops. You'll want to test it! It's because xpath relies on things like "it's the fourth row" but maybe there are more or fewer licenses sometimes, right? But you know it's always a certain number from the last row, so maybe use negative numbers with `.find_elements_by_...`? This is probably a confusing explanation.*

# %%
business_info = []

mailing_address = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[0].text.strip()
#print(mailing_address)
#print("-")

location_address = driver.find_elements_by_class_name("tablecelltext")[1].find_elements_by_tag_name("td")[0].text.strip()
#print(location_address)
#print("-")

license_info = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[1].text.strip()
#print(license_info)
#print("-")

amount_paid = driver.find_elements_by_class_name("rt")[-1].text.strip()
#print(amount_paid)
#print("-")

issued_by = driver.find_elements_by_tag_name('table')[5].find_elements_by_class_name("tablecelltext")[0].text.strip()
#print(issued_by)

business_info.append({'mailing_address': mailing_address,
                     'location_address': location_address,
                     'license_info': license_info,
                     'amount_paid': amount_paid,
                     'issued_by': issued_by})

print(business_info)
# Out:
# [{'mailing_address': 'ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113', 'location_address': 'VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054', 'license_info': 'License Status: Issued\nLicense No.: 02604406\nControl No.: 02685930\nDate of Issue: 5/01/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County', 'amount_paid': '$ 94.00', 'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401'}]

# %% [markdown]
# ### Move all of this into one cell
#
# It should visit the URL, then grab the data and put it into a dictionary.

# %%
business_info = []

url = df_stores.iloc[0].url
driver.get(url)

mailing_address = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[0].text.strip()
location_address = driver.find_elements_by_class_name("tablecelltext")[1].find_elements_by_tag_name("td")[0].text.strip()
license_info = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[1].text.strip()
amount_paid = driver.find_elements_by_class_name("rt")[-1].text.strip()
issued_by = driver.find_elements_by_tag_name('table')[5].find_elements_by_class_name("tablecelltext")[0].text.strip()
business_info.append({'mailing_address': mailing_address,
                     'location_address': location_address,
                     'license_info': license_info,
                     'amount_paid': amount_paid,
                     'issued_by': issued_by})

print(business_info)
# Out:
# [{'mailing_address': 'ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113', 'location_address': 'VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054', 'license_info': 'License Status: Issued\nLicense No.: 02604406\nControl No.: 02685930\nDate of Issue: 5/01/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County', 'amount_paid': '$ 94.00', 'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401'}]

# %% [markdown]
# ### Change it into a function
#
# You'll want to have this function accept a `row`, and send back a `pd.Series`. You can just use `pd.Series(your_dictionary)` (but it better have a better name than `your_dictionary`!).
#
# - *TIP: Make sure you `return` something!*
# - *TIP: Make sure you change everything to reflect the row's url, not the URL you typed in*

# %%
business_info = []

def get_business_info(row):
    url = row.url
    driver.get(url)

    mailing_address = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[0].text.strip()
    location_address = driver.find_elements_by_class_name("tablecelltext")[1].find_elements_by_tag_name("td")[0].text.strip()
    license_info = driver.find_elements_by_class_name("tablecelltext")[0].find_elements_by_tag_name("td")[1].text.strip()
    amount_paid = driver.find_elements_by_class_name("rt")[-1].text.strip()
    issued_by = driver.find_elements_by_tag_name('table')[5].find_elements_by_class_name("tablecelltext")[0].text.strip()
    
    return {'mailing_address': mailing_address,
                         'location_address': location_address,
                         'license_info': license_info,
                         'amount_paid': amount_paid,
                         'issued_by': issued_by,
                        'url' : url
           }

# %% [markdown]
# ### Use your dataframe and `.apply` to pull all of the data from the vape shops
#
# Once you know it's working, use the whole
#
# - *TIP: Try using it with `.head(3)` first*
# - *TIP: You'll want to use `.apply` with your new function*
# - *TIP: Issued By and Total Paid are goign to give you problems if you tried to use xpath! Try checking the classes and think about find_elementSSSSS and working backwards instead of forwards.*
# - *TIP: You might need a `try`/`except`*
# - *TIP: Make sure you're using `axis=1`*
# - *TIP: Use `.join` the big thing with all of the `dfs` - make sure you name them right!*

# %%
df_store_info = df_stores.apply(get_business_info, axis=1)
df_store_info = list(df_store_info)
df_store_info = pd.DataFrame(df_store_info)
df_store_info.head()
# Out:
#                                                               mailing_address  \
# 0            ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 1                                               DISBROW II EMERSON HARRINGTON
# 2                                              DISCOUNT TOBACCO EDGEWATER INC
# 3                                                  DISCOUNT TOBACCO ESSEX LLC
# 4  HEALTHIER CHOICES LLC\n356 ROMANCOKE ROAD\nSUITE 1\nSTEVENSVILLE, MD 21666
#
#                                                 location_address  \
# 0      VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 1  VAPE LOFT THE\n167 MITCHELLS CHANCE ROAD\nEDGEWATER, MD 21037
# 2                VAPE N CIGAR\n12 MAYO ROAD\nEDGEWATER, MD 21037
# 3        VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 4     VAPE BIRD II\n2640 CENTREVILLE ROAD\nCENTREVILLE, MD 21617
#
#                                                                                                                                                                  license_info  \
# 0  License Status: Issued\nLicense No.: 02604406\nControl No.: 02685930\nDate of Issue: 5/01/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
# 1  License Status: Issued\nLicense No.: 02610340\nControl No.: 02686069\nDate of Issue: 4/09/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
# 2  License Status: Issued\nLicense No.: 02611281\nControl No.: 02611281\nDate of Issue: 5/05/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
# 3       License Status: Issued\nLicense No.: 13640664\nControl No.: 13856368\nDate of Issue: 10/28/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 13 Howard County
# 4          License Status: Issued\nLicense No.: 17665504\nControl No.: 17368880\nDate of Issue: 7/09/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 17 Centreville
#
#   amount_paid  \
# 0     $ 94.00
# 1    $ 154.00
# 2    $ 213.00
# 3    $ 135.00
# 4     $ 54.00
#
#                                                                                          issued_by  \
# 0   SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 1   SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 2   SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 3   WAYNE A. ROBEY, CLERK OF CIRCUIT COURT\n6095 MARSHALEE DRIVE STE 120\nELKRIDGE, MARYLAND 21075
# 4  KATHERINE B. HAGER, CLERK OF CIRCUIT COURT\n200 N. COMMERCE STREET\nCENTREVILLE, MARYLAND 21617
#
#                                                                            url
# 0  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=EhcRmaKpHvo%3D
# 1  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AQQvPUEPdBc%3D
# 2  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rpdCUfaGICI%3D
# 3  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Ofer17GbEqI%3D
# 4  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YrpYy3sMDmo%3D

# %%
df_final = df_stores_with_pending.merge(df_store_info, 
                                        how = 'left',
                                        left_on='url', 
                                        right_on='url')
df_final
# Out:
#                 store  \
# 0     VAPE IT STORE I
# 1    VAPE IT STORE II
# 2         VAPEPAD THE
# 3       VAPE LOFT THE
# 4        VAPE N CIGAR
# 5        VAPE N CIGAR
# 6           VAPE DOJO
# 7        VAPE BIRD II
# 8           VAPE BIRD
# 9   VAPORFI SOUTHSIDE
# 10         VAPE DO JO
# 11        VAPE PLANET
# 12          VAPE PLUS
# 13        VAPE JUNGLE
# 14      VAPE JUNGLE 4
# 15        VAPE SOCIAL
# 16        VAPE SWITCH
# 17          VAPEWERKS
# 18          VAPIST MD
# 19     VAPOR EMPORIUM
# 20        VAPOR VILLA
# 21        VAPOR VILLA
# 22      VAPORS LOUNGE
# 23    VAPERS RING THE
#
#                                                                               url  \
# 0                                                                         pending
# 1                                                                         pending
# 2     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=EhcRmaKpHvo%3D
# 3     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AQQvPUEPdBc%3D
# 4     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rpdCUfaGICI%3D
# 5     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Ofer17GbEqI%3D
# 6                                                                         pending
# 7     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YrpYy3sMDmo%3D
# 8   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=8AvW%2FHiyaXQ%3D
# 9     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rftTtYeKd8U%3D
# 10                                                                        pending
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XLkC%2FxK0l1o%3D
# 12                                                                        pending
# 13    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=INj8yEazOBc%3D
# 14    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=K5SzjPZXD5g%3D
# 15    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=c7cwQbw6RrQ%3D
# 16                                                                        pending
# 17                                                                        pending
# 18  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=1Lwhqri%2Byjw%3D
# 19    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=MnOzyxlAHaA%3D
# 20  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=xQmQBJ%2F9Z4I%3D
# 21    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=uTwNVtGVItQ%3D
# 22    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mnI6lBaxYew%3D
# 23    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=uOemx26D8e0%3D
#
#                                                                mailing_address  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2             ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 3                                                DISBROW II EMERSON HARRINGTON
# 4                                               DISCOUNT TOBACCO EDGEWATER INC
# 5                                                   DISCOUNT TOBACCO ESSEX LLC
# 6                                                                          NaN
# 7   HEALTHIER CHOICES LLC\n356 ROMANCOKE ROAD\nSUITE 1\nSTEVENSVILLE, MD 21666
# 8                                                              HUTCH VAPES LLC
# 9                                                              JEN S VAPOR LLC
# 10                                                                         NaN
# 11                                                                     RNS LLC
# 12                                                                         NaN
# 13               VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH ROAD\nOWINGS, MD 20736
# 14                 VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH RD\nOWINGS, MD 20736
# 15                                                             VAPE SOCIAL LLC
# 16                                                                         NaN
# 17                                                                         NaN
# 18                     VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601
# 19                                                       VAPOR EMPORIUM MD LLC
# 20                                                            VAPOR VILLA CORP
# 21                                                            VAPOR VILLA CORP
# 22                                                           VAPORS LOUNGE LLC
# 23                           YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113
#
#                                                           location_address  \
# 0                                                                      NaN
# 1                                                                      NaN
# 2                VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 3            VAPE LOFT THE\n167 MITCHELLS CHANCE ROAD\nEDGEWATER, MD 21037
# 4                          VAPE N CIGAR\n12 MAYO ROAD\nEDGEWATER, MD 21037
# 5                  VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 6                                                                      NaN
# 7               VAPE BIRD II\n2640 CENTREVILLE ROAD\nCENTREVILLE, MD 21617
# 8            VAPE BIRD\n356 ROMANCOKE ROAD SUITE 1\nSTEVENSVILLE, MD 21666
# 9                VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230
# 10                                                                     NaN
# 11           VAPE PLANET\n21632 GREAT MILLS ROAD\nLEXINGTON PARK, MD 20653
# 12                                                                     NaN
# 13               VAPE JUNGLE\n2070 CRAIN HIGHWAY UNIT F\nWALDORF, MD 20601
# 14                 VAPE JUNGLE 4\n5486 SOUTHERN MD BLVD\nLOTHIAN, MD 20711
# 15              VAPE SOCIAL\n16521 S FREDERICK AVE\nGAITHERSBURG, MD 20877
# 16                                                                     NaN
# 17                                                                     NaN
# 18                  VAPIST MD\n6321 OLD BRANCH AVE\nCAMP SPRINGS, MD 20748
# 19  VAPOR EMPORIUM\n11717 OLD NATIONAL PIKE\nUNIT 3B\nNEW MARKET, MD 21774
# 20       VAPOR VILLA\n730 FREDERICK ROAD\nSUITE 202\nCATONSVILLE, MD 21228
# 21          VAPOR VILLA\n1913 LANSDOWNE ROAD\nSUITE E\nBALTIMORE, MD 21227
# 22         VAPORS LOUNGE\n28943 THREE NOTCH ROAD\nMECHANICSVILLE, MD 20659
# 23          VAPERS RING THE\n1159 ANNAPOLIS RD\nSUITE A\nODENTON, MD 21113
#
#                                                                                                                                                                      license_info  \
# 0                                                                                                                                                                             NaN
# 1                                                                                                                                                                             NaN
# 2      License Status: Issued\nLicense No.: 02604406\nControl No.: 02685930\nDate of Issue: 5/01/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
# 3      License Status: Issued\nLicense No.: 02610340\nControl No.: 02686069\nDate of Issue: 4/09/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
# 4      License Status: Issued\nLicense No.: 02611281\nControl No.: 02611281\nDate of Issue: 5/05/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
# 5           License Status: Issued\nLicense No.: 13640664\nControl No.: 13856368\nDate of Issue: 10/28/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 13 Howard County
# 6                                                                                                                                                                             NaN
# 7              License Status: Issued\nLicense No.: 17665504\nControl No.: 17368880\nDate of Issue: 7/09/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 17 Centreville
# 8      License Status: Issued\nLicense No.: 17665514\nControl No.: 17980116\nDate of Issue: 7/21/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 17 Queen Anne's County
# 9           License Status: Issued\nLicense No.: 30680742\nControl No.: 30190160\nDate of Issue: 5/15/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 30 Baltimore City
# 10                                                                                                                                                                            NaN
# 11       License Status: Issued\nLicense No.: 18667704\nControl No.: 18667704\nDate of Issue: 7/14/2020\nMonths Paid: 10\nExp. Date: 4/30/2021\nSubdivision: 18 St. Mary's County
# 12                                                                                                                                                                            NaN
# 13          License Status: Issued\nLicense No.: 08630779\nControl No.: 08844059\nDate of Issue: 6/10/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 08 Charles County
# 14     License Status: Issued\nLicense No.: 02611618\nControl No.: 02611618\nDate of Issue: 10/14/2020\nMonths Paid: 7\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
# 15            License Status: Issued\nLicense No.: 15653996\nControl No.: 15728050\nDate of Issue: 7/28/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 15 Gaithersburg
# 16                                                                                                                                                                            NaN
# 17                                                                                                                                                                            NaN
# 18  License Status: Issued\nLicense No.: 16664255\nControl No.: 16166805\nDate of Issue: 8/26/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 16 Prince George's County
# 19        License Status: Issued\nLicense No.: 10634794\nControl No.: 10954003\nDate of Issue: 4/24/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 10 Frederick County
# 20        License Status: Issued\nLicense No.: 03622173\nControl No.: 03696931\nDate of Issue: 5/06/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 03 Baltimore County
# 21        License Status: Issued\nLicense No.: 03622172\nControl No.: 03696574\nDate of Issue: 5/06/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 03 Baltimore County
# 22       License Status: Issued\nLicense No.: 18667461\nControl No.: 18877819\nDate of Issue: 5/26/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 18 St. Mary's County
# 23     License Status: Issued\nLicense No.: 02610667\nControl No.: 02931736\nDate of Issue: 5/26/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County
#
#    amount_paid  \
# 0          NaN
# 1          NaN
# 2      $ 94.00
# 3     $ 154.00
# 4     $ 213.00
# 5     $ 135.00
# 6          NaN
# 7      $ 54.00
# 8      $ 59.00
# 9     $ 189.00
# 10         NaN
# 11    $ 188.00
# 12         NaN
# 13    $ 186.00
# 14     $ 99.75
# 15     $ 59.00
# 16         NaN
# 17         NaN
# 18    $ 329.00
# 19    $ 154.00
# 20     $ 83.00
# 21     $ 83.00
# 22     $ 94.00
# 23    $ 154.00
#
#                                                                                                   issued_by
# 0                                                                                                       NaN
# 1                                                                                                       NaN
# 2            SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 3            SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 4            SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 5            WAYNE A. ROBEY, CLERK OF CIRCUIT COURT\n6095 MARSHALEE DRIVE STE 120\nELKRIDGE, MARYLAND 21075
# 6                                                                                                       NaN
# 7           KATHERINE B. HAGER, CLERK OF CIRCUIT COURT\n200 N. COMMERCE STREET\nCENTREVILLE, MARYLAND 21617
# 8           KATHERINE B. HAGER, CLERK OF CIRCUIT COURT\n200 N. COMMERCE STREET\nCENTREVILLE, MARYLAND 21617
# 9          MARILYN BENTLEY, CLERK CIRCUIT COURT\n100 N. CALVERT STREET, ROOM 627\nBALTIMORE, MARYLAND 21202
# 10                                                                                                      NaN
# 11                                                                                          Tag Number: NEW
# 12                                                                                                      NaN
# 13                  SHARON L. HANCOCK, CLERK OF CIRCUIT COURT\n200 CHARLES STREET\nLA PLATA, MARYLAND 20646
# 14           SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 15  BARBARA H. MEIKLEJOHN, CLERK OF CIRCUIT COURT\n50 MARYLAND AVENUE, ROOM 1300\nROCKVILLE, MARYLAND 20850
# 16                                                                                                      NaN
# 17                                                                                                      NaN
# 18          MAHASIN EL AMIN, CLERK OF CIRCUIT COURT\n14735 MAIN STREET\nUPPER MARLBORO, MARYLAND 20772-9987
# 19                SANDRA DALTON, CLERK OF CIRCUIT COURT\n100 WEST PATRICK STREET\nFREDERICK, MARYLAND 21701
# 20                       JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754
# 21                       JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754
# 22   DEBRA J. BURCH CLERK OF CIRCUIT COURT\n41605 COURTHOUSE DRIVE, PO BOX 676\nLEONARDTOWN, MARYLAND 20650
# 23           SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401

# %% [markdown]
# ## Save as `vape-total.csv`
#
# Make sure you don't save the index! Open it up in a text editor or Excel to make sure it's correct.

# %%
df_final.to_csv("vape-total.csv", index=False)
